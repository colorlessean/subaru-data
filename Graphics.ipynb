# %%
import pandas as pd
import matplotlib.pyplot as plt

# hardcoded data columns
# may have to modify csv file column headers to get rid of special characters
data_columns = ['Time (sec)','Calculated Load (g/rev)','Dyn Adv Mult (DAM)','Dynamic Adv','Feedback Knock','Fine Knock Learn','Ignition Timing','MAF (g/s)','MAF Volt (V)','RPM (RPM)','TD Boost Error (psi)','Throttle Pos (%)','Wastegate Duty (%)','AP Info:[AP3-SUB-001 v1.7.3.1-17014][2005 USDM Impreza WRX][Reflash: Stage2 ACN91 v350 HWG.ptm - Realtime: Stage2 ACN91 v350 HWG.ptm]']

# import csv file and map the columns
data_file = pd.read_csv(r'1_4913477646442037474.csv', encoding='ISO-8859-1')
data_frame = pd.DataFrame(data_file, columns=data_columns)

# get a list out of the pandas series object
time = data_frame[data_columns[0]].tolist()
rpm = data_frame[data_columns[9]].tolist()

plt.plot(time, rpm)
plt.xlabel(data_columns[0])
plt.ylabel(data_columns[9])
# Out:
# Text(0, 0.5, 'RPM (RPM)')

# %% [markdown]
# ###
